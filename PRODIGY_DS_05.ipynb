# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_USA=pd.read_csv("RTA Dataset.csv")

# %%
df_USA.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df_USA.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
df_USA.dtypes.value_counts()
# Out:
# object    30
# int64      2
# Name: count, dtype: int64

# %% [markdown]
# # Shape of original data

# %%
df_USA.shape   # USA DATASET
# Out:
# (12316, 32)

# %% [markdown]
# num_col=df.select_dtypes('number')
# cat_col=df.select_dtypes('object')
# bool_col=df.select_dtypes('bool')
# float_col=df.select_dtypes('float64')
# float_col=df.select_dtypes('int64')

# %% [markdown]
# missing_data = df.isna().sum(axis=0).sort_values(ascending=True)
# missing_data = missing_data.to_frame()
# missing_data.columns = ['missing_count']
# missing_data = missing_data.loc[missing_data['missing_count']>0]
#
# missing_data

# %%
# COLUMN NUMBER has highest no of null value , we cam drop that col further

# %%
df_USA.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
import pandas as pd

# Sample DataFrame creation (replace this with your actual DataFrame loading code)
data = {'state': ['California', 'Texas', 'New York', 'California', 'Texas']}
df_USA = pd.DataFrame(data)

# Verify column names
print("Column names:", df_USA.columns)

# Access the column and get unique values
if 'state' in df_USA.columns:
    unique_states = df_USA['state'].unique()
    print("Unique states:", unique_states)
else:
    print("The DataFrame does not contain the 'state' column.")
# Out:
# Column names: Index(['state'], dtype='object')
# Unique states: ['California' 'Texas' 'New York']

# %%
df1=df_USA[df_USA['state']=='CA']

# %%
import pandas as pd

# Create a sample DataFrame
df1 = pd.DataFrame({
    'ID': ['123', '4567', '89a', '100b']
})

# Extract numeric parts and convert to integer
df1['IDD'] = df1['ID'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

print(df1)
# Out:
#      ID   IDD
# 0   123   123
# 1  4567  4567
# 2   89a    89
# 3  100b   100

# %%
df1
# Out:
#      ID   IDD
# 0   123   123
# 1  4567  4567
# 2   89a    89
# 3  100b   100

# %%
#df1['ID'].astype('int64')
#df1['ID'] = df1['ID'].astype(int)

# %%
df1.head()
# Out:
#      ID   IDD
# 0   123   123
# 1  4567  4567
# 2   89a    89
# 3  100b   100

# %%
df1.shape
# Out:
# (4, 2)

# %%
df1.columns
# Out:
# Index(['ID', 'IDD'], dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
import pandas as pd

# Sample DataFrame creation (replace with your actual DataFrame loading code)
data = {'Precipitation(in)': [0.2, None, 0.5, None, 0.7]}
df1 = pd.DataFrame(data)

# Verify column names
print("Column names:", df1.columns)

# Remove any extra spaces in column names
df1.columns = df1.columns.str.strip()

# Drop rows where 'Precipitation(in)' is NaN
d1f = df1.dropna(subset=['Precipitation(in)'])
print(d1f)
# Out:
# Column names: Index(['Precipitation(in)'], dtype='object')
#    Precipitation(in)
# 0                0.2
# 2                0.5
# 4                0.7

# %%
df1.shape
# Out:
# (5, 1)

# %%
import pandas as pd

# Sample DataFrame creation (replace with your actual DataFrame loading code)
data = {
    'Temperature(F)': [72, None, 68],
    'Wind_Chill(F)': [None, 64, 62],
    'Humidity(%)': [80, 70, None],
    'Pressure(in)': [29.9, None, 30.1],
    'Visibility(mi)': [10, 8, None],
    'Wind_Direction': ['N', 'E', 'S'],
    'Wind_Speed(mph)': [5, None, 7],
    'Weather_Condition': ['Clear', 'Cloudy', 'Rain']
}
df1 = pd.DataFrame(data)

# Verify column names
print("Column names:", df1.columns)

# Remove any extra spaces in column names
df1.columns = df1.columns.str.strip()

# Drop rows where specified columns have NaN values
df1_cleaned = df1.dropna(subset=[
    'Temperature(F)',
    'Wind_Chill(F)',
    'Humidity(%)',
    'Pressure(in)',
    'Visibility(mi)',
    'Wind_Direction',
    'Wind_Speed(mph)',
    'Weather_Condition'
])

print(df1_cleaned)
# Out:
# Column names: Index(['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Weather_Condition'],
#       dtype='object')
# Empty DataFrame
# Columns: [Temperature(F), Wind_Chill(F), Humidity(%), Pressure(in), Visibility(mi), Wind_Direction, Wind_Speed(mph), Weather_Condition]
# Index: []

# %%
df1.shape
# Out:
# (3, 8)

# %%
df1.isna().sum()/len(df1)*100
# Out:
# Temperature(F)       33.333333
# Wind_Chill(F)        33.333333
# Humidity(%)          33.333333
# Pressure(in)         33.333333
# Visibility(mi)       33.333333
# Wind_Direction        0.000000
# Wind_Speed(mph)      33.333333
# Weather_Condition     0.000000
# dtype: float64

# %%
# Verify columns before dropping NaNs
required_columns = ['City', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']

# Check for missing columns
missing_columns = [col for col in required_columns if col not in df1.columns]
if missing_columns:
    print(f"Missing columns: {missing_columns}")

# Proceed if all required columns are present
if not missing_columns:
    df1 = df1.dropna(subset=required_columns)
else:
    print("Cannot drop NaNs due to missing columns.")
# Out:
# Missing columns: ['City', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']
# Cannot drop NaNs due to missing columns.

# %%
df1.isna().sum()/len(df1)*100
# Out:
# Temperature(F)       33.333333
# Wind_Chill(F)        33.333333
# Humidity(%)          33.333333
# Pressure(in)         33.333333
# Visibility(mi)       33.333333
# Wind_Direction        0.000000
# Wind_Speed(mph)      33.333333
# Weather_Condition     0.000000
# dtype: float64

# %%
df1['Weather_Condition'].value_counts()
# Out:
# Weather_Condition
# Clear     1
# Cloudy    1
# Rain      1
# Name: count, dtype: int64

# %%
import pandas as pd

# Sample DataFrame creation (replace this with your actual DataFrame loading code)
data = {'side': ['left', 'right', 'left', 'right', 'center']}
df1 = pd.DataFrame(data)

# Verify column names
print("Column names:", df1.columns)

# Access the column and get unique values
if 'side' in df1.columns:
    unique_sides = df1['side'].unique()
    print("Unique sides:", unique_sides)
else:
    print("The DataFrame does not contain the 'side' column.")
# Out:
# Column names: Index(['side'], dtype='object')
# Unique sides: ['left' 'right' 'center']

# %%
import pandas as pd
import numpy as np

# Sample DataFrame creation (replace with your actual DataFrame loading code)
data = {
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df1 = pd.DataFrame(data)

# Select categorical and numerical columns
df_cat = df1.select_dtypes('object')
df_num = df1.select_dtypes(include=np.number)

# Verify columns in df_cat
print("Columns in df_cat:", df_cat.columns)

# Drop 'ID' column from df_cat if it exists
if 'ID' in df_cat.columns:
    df_cat = df_cat.drop('ID', axis=1)
    print("df_cat after dropping 'ID':")
    print(df_cat)
else:
    print("Column 'ID' not found in df_cat.")
# Out:
# Columns in df_cat: Index(['Name', 'City'], dtype='object')
# Column 'ID' not found in df_cat.

# %%
df_cat=df1.select_dtypes('object')
col_name=[]
length=[]

for i in df_cat.columns:
    col_name.append(i)
    length.append(len(df_cat[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#   feature  count_of_unique_values
# 0    Name                       3
# 1    City                       3

# %% [markdown]
# num_col=df.select_dtypes('number')
# cat_col=df.select_dtypes('object')
# bool_col=df.select_dtypes('bool')
# float_col=df.select_dtypes('float64')
# int_col=df.select_dtypes('int64')

# %%
import pandas as pd

# Sample DataFrame creation (replace this with your actual DataFrame loading code)
data = {
    'Description': ['Clear', 'Rainy', 'Cloudy'],
    'Zipcode': [10001, 90001, 60601],
    'Weather_Timestamp': ['2024-01-01 12:00:00', '2024-01-02 12:00:00', '2024-01-03 12:00:00'],
    'Temperature(F)': [72, 65, 60]
}
df1 = pd.DataFrame(data)

# Verify columns in df1
print("Columns in df1:", df1.columns)

# List of columns to drop
columns_to_drop = ['Description', 'Zipcode', 'Weather_Timestamp']

# Drop columns if they exist
df1.drop(columns=[col for col in columns_to_drop if col in df1.columns], axis=1, inplace=True)

# Verify the result
print("Columns in df1 after dropping:", df1.columns)
# Out:
# Columns in df1: Index(['Description', 'Zipcode', 'Weather_Timestamp', 'Temperature(F)'], dtype='object')
# Columns in df1 after dropping: Index(['Temperature(F)'], dtype='object')

# %%
import pandas as pd

# Example DataFrame creation
df1 = pd.DataFrame({
    'Airport_Code': ['JFK', 'LAX', 'ORD'],
    'City': ['New York', 'Los Angeles', 'Chicago']
})

# Check column names
print("Columns before deletion:", df1.columns)

# Try to delete the column
if 'Airport_Code' in df1.columns:
    df1.drop(columns=['Airport_Code'], errors='ignore', inplace=True)
    print("Column 'Airport_Code' deleted successfully.")
else:
    print("Column 'Airport_Code' does not exist.")

# Verify the result
print("Columns after deletion:", df1.columns)
# Out:
# Columns before deletion: Index(['Airport_Code', 'City'], dtype='object')
# Column 'Airport_Code' deleted successfully.
# Columns after deletion: Index(['City'], dtype='object')

# %%
df_num.columns
# Out:
# Index(['ID', 'Age'], dtype='object')

# %%
len(df_num.columns)
# Out:
# 2

# %%
df_cat.columns
# Out:
# Index(['Name', 'City'], dtype='object')

# %%
#bool_col.columns

# %%
#int_col.columns

# %%
#cat_col.head()

# %%
import pandas as pd

# Example DataFrame creation
df = pd.DataFrame({
    'city': ['New York', 'Los Angeles', 'Chicago', 'New York', 'Chicago']
})

# Calculate the number of unique values in the 'city' column
print(len(df['city'].unique()))  # Output should be 3
# Out:
# 3

# %%
#cat_col

# %%
#num_col_1=df.select_dtypes('number')

# %% [markdown]
# # Numeric Data

# %%
df_num=df1.select_dtypes(np.number)
col_name=[]
length=[]

for i in df_num.columns:
    col_name.append(i)
    length.append(len(df_num[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
# Empty DataFrame
# Columns: [feature, count_of_unique_values]
# Index: []

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame creation (make sure df_num is properly defined)
df_num = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [2, 3, 4, 5, 6]
})

# Check if df_num is empty
if df_num.empty:
    print("DataFrame is empty.")
else:
    # Calculate the correlation matrix
    corr_matrix = df_num.corr()

    # Check for NaN values and handle them
    if corr_matrix.isna().any().any():
        print("NaN values found in the correlation matrix. Handling NaNs...")
        corr_matrix = corr_matrix.fillna(0)

    # Plot heatmap
    plt.figure(figsize=(15, 9))
    sns.heatmap(corr_matrix, annot=True)
    plt.show()

# %%
cities = df1['City'].unique()
len(cities)
# Out:
# 3

# %%
accidents_by_cities = df1['City'].value_counts()
accidents_by_cities
# Out:
# City
# New York       1
# Los Angeles    1
# Chicago        1
# Name: count, dtype: int64

# %%
#top 10 cities by number of accident
accidents_by_cities[:10]
# Out:
# City
# New York       1
# Los Angeles    1
# Chicago        1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,5))
accidents_by_cities[:10].plot(kind='bar')
ax.set(title = 'Top 10 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
plt.show()

# %%
# Print column names to verify
print(df1.columns)

# If 'Severity' is not in the column names, check for typos or leading/trailing spaces
# Remove extra spaces from column names
df1.columns = df1.columns.str.strip()

# Verify column names again
print(df1.columns)

# Check if 'Severity' exists
if 'Severity' in df1.columns:
    accidents_severity = df1.groupby('Severity').count()['ID']
    print(accidents_severity)
else:
    print("Column 'Severity' does not exist in the DataFrame.")
# Out:
# Index(['City'], dtype='object')
# Index(['City'], dtype='object')
# Column 'Severity' does not exist in the DataFrame.

# %%
import matplotlib.pyplot as plt

# Assuming df1 is defined and has the necessary columns
# Create accidents_severity
try:
    accidents_severity = df1.groupby('Severity').count()['ID']
except KeyError:
    print("Ensure that 'Severity' and 'ID' columns are present in df1.")
    accidents_severity = pd.Series()  # Define as empty Series to avoid further errors

# Check if accidents_severity is defined and not empty
if not accidents_severity.empty:
    fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(aspect="equal"))

    # Define labels for the pie chart
    labels = accidents_severity.index.tolist()
    
    # Create pie chart
    plt.pie(accidents_severity, labels=labels,
            autopct='%1.1f%%', pctdistance=0.85)
    
    # Draw a circle in the center to make it look like a donut chart
    circle = plt.Circle((0, 0), 0.5, color='white')
    p = plt.gcf()
    p.gca().add_artist(circle)
    
    # Set title and layout
    ax.set_title("Accidents by Severity", fontdict={'fontsize': 16})
    plt.tight_layout()
    
    # Show plot
    plt.show()
else:
    print("No data available to plot.")
# Out:
# Ensure that 'Severity' and 'ID' columns are present in df1.
# No data available to plot.

# %%
import pandas as pd

# Example DataFrame creation (ensure df1 is correctly defined)
df1 = pd.DataFrame({
    'start_Time': ['2024-08-26 08:00:00', '2024-08-26 09:00:00'],
    'end_Time': ['2024-08-26 10:00:00', '2024-08-26 11:00:00']
})

# Print column names to verify the column exists
print("Columns in DataFrame:", df1.columns)

# Check if 'start_Time' column exists and get its dtype
if 'start_Time' in df1.columns:
    print(df1['start_Time'].dtype)
else:
    print("Column 'start_Time' does not exist.")
# Out:
# Columns in DataFrame: Index(['start_Time', 'end_Time'], dtype='object')
# object

# %%
import pandas as pd

# Example DataFrame creation (ensure df1 is correctly defined)
df1 = pd.DataFrame({
    'start_Time': ['2024-08-26 08:00:00', '2024-08-26 09:00:00'],
    'end_Time': ['2024-08-26 10:00:00', '2024-08-26 11:00:00']
})

# Print column names to verify the column exists
print("Columns in DataFrame:", df1.columns)

# Check if 'end_Time' column exists and get its dtype
if 'start_Time' in df1.columns:
    print(df1['end_Time'].dtype)
else:
    print("Column 'end_Time' does not exist.")
# Out:
# Columns in DataFrame: Index(['start_Time', 'end_Time'], dtype='object')
# object

# %%
import pandas as pd

# Example DataFrame creation with correct column names
df1 = pd.DataFrame({
    'Start_Time': ['2024-08-26 08:00:00', '2024-08-26 09:00:00'],
    'End_Time': ['2024-08-26 10:00:00', '2024-08-26 11:00:00']
})

# Print column names to verify
print("Columns before conversion:", df1.columns)

# Strip any leading or trailing whitespace from column names
df1.columns = df1.columns.str.strip()

# Convert data types
df1 = df1.astype({'Start_Time': 'datetime64[ns]', 'End_Time': 'datetime64[ns]'})

# Verify the dtype conversion
print(df1['Start_Time'].dtypes)
print(df1['End_Time'].dtypes)
# Out:
# Columns before conversion: Index(['Start_Time', 'End_Time'], dtype='object')
# datetime64[ns]
# datetime64[ns]

# %%
import pandas as pd

# Example DataFrame creation
df1 = pd.DataFrame({
    'Start_Time': pd.date_range(start='2024-08-26', periods=10, freq='D'),
    'End_Time': pd.date_range(start='2024-08-27', periods=10, freq='D')
})

# Check DataFrame shape and index
print("DataFrame shape:", df1.shape)
print("DataFrame index:", df1.index)

# Safely access a specific row by position
row_index = 5  # Adjust this as needed
if row_index < len(df1):
    print(df1['Start_Time'].iloc[row_index])
else:
    print(f"Row index {row_index} is out of range.")
# Out:
# DataFrame shape: (10, 2)
# DataFrame index: RangeIndex(start=0, stop=10, step=1)
# 2024-08-31 00:00:00

# %%
import pandas as pd

# Example DataFrame creation (make sure this matches your actual DataFrame structure)
df1 = pd.DataFrame({
    'Start_Time': pd.date_range(start='2024-08-26', periods=10, freq='D'),
    'End_Time': pd.date_range(start='2024-08-27', periods=10, freq='D')
})

# Check the DataFrame's index range and length
print("DataFrame index range:", df1.index)
print("Number of rows:", len(df1))

# Attempt to access row by position
index_to_check = 5  # Adjust this index for your needs
if len(df1) > index_to_check:
    print("End_Time at position", index_to_check, ":", df1['End_Time'].iloc[index_to_check])
else:
    print(f"Index {index_to_check} is out of range.")

# Check column names
print("Columns in DataFrame:", df1.columns)
# Out:
# DataFrame index range: RangeIndex(start=0, stop=10, step=1)
# Number of rows: 10
# End_Time at position 5 : 2024-09-01 00:00:00
# Columns in DataFrame: Index(['Start_Time', 'End_Time'], dtype='object')

# %%
df1['start_date'] = [d.date() for d in df1['Start_Time']]
df1['start_time'] = [d.time() for d in df1['Start_Time']]

# %%
df1['end_date'] = [d.date() for d in df1['End_Time']]
df1['end_time'] = [d.time() for d in df1['End_Time']]

# %%
df1['end_time']
# Out:
# 0    00:00:00
# 1    00:00:00
# 2    00:00:00
# 3    00:00:00
# 4    00:00:00
# 5    00:00:00
# 6    00:00:00
# 7    00:00:00
# 8    00:00:00
# 9    00:00:00
# Name: end_time, dtype: object

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24)

plt.xlabel("Start Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24)

plt.xlabel("End_Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
del df1['Start_Time']
del df1['End_Time']

# %%
#df.head()

# %%
# %matplotlib inline
import os

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data creation
df = pd.DataFrame({
    'weather': ['Clear', 'Rain', 'Fog', 'Clear', 'Rain', 'Clear', 'Snow', 'Fog', 'Clear', 'Rain', 'Snow', 'Clear']
})

# Compute weather conditions count
weather_conditions = df['weather'].value_counts()

# Plot the top 20 weather conditions
fig, ax = plt.subplots(figsize=(8, 5))
weather_conditions.sort_values(ascending=False)[:20].plot(kind='bar', ax=ax)
ax.set(title='Weather Conditions at Time of Accident Occurrence',
       xlabel='Weather',
       ylabel='Accidents Count')
plt.show()

# %% [markdown]
# #  most accidents happened when the weather was 'fair'. Perhaps weather (bad weather) was not a big contributing factor to accidents.

# %%
#df_num.head()

# %%
# shape of original data -> 2845342 rows

# %%
df.shape  # shape of data after removing null values
# Out:
# (12, 1)

# %%
df_num.shape
# Out:
# (5, 3)

# %%
# Check if 'Severity' exists in the DataFrame
if 'Severity' in df1.columns:
    # Group by 'Severity' and count the occurrences of 'IDD'
    result = df1.groupby('Severity').count()['IDD']
    print(result)
else:
    print("Column 'Severity' does not exist in the DataFrame.")
    print("Available columns:", df1.columns)
# Out:
# Column 'Severity' does not exist in the DataFrame.
# Available columns: Index(['start_date', 'start_time', 'end_date', 'end_time'], dtype='object')

# %%
# scatter plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a dummy DataFrame
test_df = pd.DataFrame({
    'Severity': [1, 2, 3, 4],
    'Start_Lat': [34.05, 36.16, 40.71, 37.77]
})

# Generate a scatter plot
test_df.plot(kind='scatter', x='Severity', y='Start_Lat', figsize=(10, 6))

# Set axis labels
plt.xlabel('Severity', fontsize=12)
plt.ylabel('Start Latitude', fontsize=12)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create a dummy DataFrame
test_df = pd.DataFrame({
    'Start_Lat': [34.05, 36.16, 40.71, 37.77],
    'Start_Lng': [-118.24, -115.15, -74.01, -122.42]
})

# Generate the joint plot
sns.jointplot(x='Start_Lat', y='Start_Lng', data=test_df, height=10)

# Set axis labels
plt.xlabel('Start Longitude', fontsize=12)
plt.ylabel('Start Latitude', fontsize=12)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a simple DataFrame
test_df = pd.DataFrame({
    'End_Lat': [34.05, 36.16, 40.71, 37.77],
    'End_Lng': [-118.24, -115.15, -74.01, -122.42]
})

# Generate the joint plot
sns.jointplot(x='End_Lat', y='End_Lng', data=test_df, height=10)

# Set axis labels
plt.xlabel('End Longitude', fontsize=12)
plt.ylabel('End Latitude', fontsize=12)

# Show the plot
plt.show()
